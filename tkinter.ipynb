# %%
from tkinter import*

a=int(input("Enter value A:"))
b=int(input("Enter value B:"))
def add(a,b):
    print("addtion =",a+b)
def sub(a,b):
    print("subtraction=",a-b)
def mul(a,b):
    print("Multiplication =",a*b)
def div(a,b):
    print("division =",a/b)
root=Tk()
root.geometry("300x300")
# root.configure(bg="black")
root.title("By Vipul")
root.iconbitmap("images.ico")


frame=Frame(root,borderwidth=6,relief=SUNKEN)
frame.pack(side=LEFT,anchor="nw")

b1=Button(frame,fg="red",text="add",command=add(a,b))
b1.pack(side=LEFT,padx=20)
b1=Button(frame,fg="red",text="sub",command=sub(a,b))
b1.pack(side=LEFT,padx=20)
b1=Button(frame,fg="red",text="mul",command=mul(a,b))
b1.pack(side=LEFT,padx=20)
b1=Button(frame,fg="red",text="div",command=div(a,b))
b1.pack(side=LEFT,padx=20)

root.mainloop()
# Out:
# addtion = 57
# subtraction= -33
# Multiplication = 540
# division = 0.26666666666666666

# %%
from tkinter import *
def getvalue():
    print("name of user ",uservalue.get())
    print("password is",passvalue.get())


root=Tk()
root.geometry("300x300")
root.title("By Vipul")
root.iconbitmap("images.ico")
# root.configure(bg="black")
user=Label(root,text="Username")
password=Label(root,text="Password")
user.grid(row=0,column=0)   
password.grid(row=1,column=0)

uservalue=StringVar()
passvalue=StringVar()

userentry=Entry(root,textvariable=uservalue)
userentry.grid(row=0,column=1)
passentry=Entry(root,textvariable=passvalue)
passentry.grid(row=1,column=1)

Button(text="submit",command=getvalue).grid()

root.mainloop()

# %%
from tkinter import*
root=Tk()
root.geometry('500x500')
root.title("By Vipul")
root.iconbitmap("images.ico")
def getvalue():
    print("Submitting Your Data")
    print(f"{namevalue.get(),mobilevalue.get(),gendervalue.get(),emergencyvalue.get(),foodservicesvalue.get()}" ) 

    with open("record.txt","a") as f:
        f.write(f"{namevalue.get(),mobilevalue.get(),gendervalue.get(),emergencyvalue.get(),foodservicesvalue.get()}\n")

a=Label(root,text="Welcome to My profile",font='comicsansms 12 bold').grid(row=0,column=5)


name=Label(root,text="Name").grid(row=2,column=0)
mobile=Label(root,text="Mobile").grid(row=3,column=0)
gender=Label(root,text="Gender").grid(row=4,column=0)
emergency=Label(root,text="Emergency").grid(row=5,column=0)
foodservices=Label(root,text="foodservices").grid(row=5,column=0)

namevalue=StringVar()
mobilevalue=StringVar()
gendervalue=StringVar()
emergencyvalue=StringVar()
foodservicesvalue=IntVar()

nameentry=Entry(root,textvariable=namevalue).grid(row=2,column=5)
mobileentry=Entry(root,textvariable=mobilevalue).grid(row=3,column=5)
genderentry=Entry(root,textvariable=gendervalue).grid(row=4,column=5)
emergencyentry=Entry(root,textvariable=emergencyvalue).grid(row=5,column=5)

foodservices=Checkbutton(text="wnat to make your meal?",variable=foodservicesvalue).grid(row=6,column=5)
Button(text="submit",command=getvalue).grid(row=7,column=5)


root.mainloop()
# Out:
# Submitting Your Data
# ('', '', '', '', 1)

# %%
from tkinter import*
root=Tk()
root.geometry('500x500')
root.title("By Vipul")
root.iconbitmap("images.ico")

canvas_widget=Canvas(root, width=500, height=500)
# canvas_widget.minsize(500,500)
# canvas_widget.maxsize(500,500)
canvas_widget.pack()

canvas_widget.create_line(0,0,500,500,fill="red")
canvas_widget.create_line(0,500,500,0,fill="red")
canvas_widget.create_rectangle(120,120,0,0,fill="red")
canvas_widget.create_rectangle(120,120,0,0,fill="red")

canvas_widget.create_text(20,20,text="vipul")
canvas_widget.create_oval(340,233,244,355)

root.mainloop()

# %%
from tkinter import*
root=Tk()
root.geometry('500x500')
root.title("By Vipul")
root.iconbitmap("images.ico")

mainmenu=Menu(root)

m1=Menu(mainmenu,tearoff=0)
m1.add_command(label="save",command="")
m1.add_command(label="save",command="")
m1.add_command(label="save",command="")
m1.add_command(label="save",command="")
mainmenu.add_cascade(label="file",menu=m1)

m2=Menu(mainmenu,tearoff=0)
m2.add_command(label="save",command="")
m2.add_command(label="save",command="")
m2.add_command(label="save",command="")
m2.add_command(label="save",command="")
mainmenu.add_cascade(label="command",menu=m2)



root.config(menu=mainmenu)


root.mainloop()

# %%
from tkinter import*
import tkinter.messagebox as tmsg
root=Tk()
root.geometry('500x500')
root.title("By Vipul")
root.iconbitmap("images.ico")

def help():
    print("how can i help you?")
    a=tmsg.showinfo('help',"vipul help you")
    
def rateus():
    print("how can i rate")
    value=tmsg.askquestion("how was your experience","its good?")
    if value=="yes":
        msg=print("rate us on aap store")
    else:
        msg=print("WHAT we have to improove?")
    tmsg.showinfo("ok", msg)

def vipul():
    ans=tmsg.askretrycancel("what about friend requests?","vipul is good boy")
    if ans:
        print("nothings to work")
    else:
        print("okey")

mainmenu=Menu(root)

m1=Menu(mainmenu,tearoff=0)
m1.add_command(label="save",command="")
m1.add_command(label="save",command="")
m1.add_command(label="save",command="")
m1.add_command(label="save",command="")
mainmenu.add_cascade(label="file",menu=m1)

m2=Menu(mainmenu,tearoff=0)
m2.add_command(label="save",command="")
m2.add_command(label="save",command="")
m2.add_command(label="save",command="")
m2.add_command(label="save",command="")
mainmenu.add_cascade(label="command",menu=m2)

m3=Menu(mainmenu,tearoff=0)
m3.add_command(label="help",command=help)
m3.add_command(label="Rate Us",command=rateus)
m3.add_command(label="Be Friends",command=vipul)
mainmenu.add_cascade(label="help",menu=m3)

root.config(menu=mainmenu)


root.mainloop()
# Out:
# nothings to work
# how can i help you?

# %%
# Python program to create a simple GUI
# calculator using Tkinter

# import everything from tkinter module
from tkinter import *

# globally declare the expression variable
expression = ""


# Function to update expression
# in the text entry box
def press(num):
	# point out the global expression variable
	global expression

	# concatenation of string
	expression = expression + str(num)

	# update the expression by using set method
	equation.set(expression)


# Function to evaluate the final expression
def equalpress():
	# Try and except statement is used
	# for handling the errors like zero
	# division error etc.

	# Put that code inside the try block
	# which may generate the error
	try:

		global expression

		# eval function evaluate the expression
		# and str function convert the result
		# into string
		total = str(eval(expression))

		equation.set(total)

		# initialize the expression variable
		# by empty string
		expression = ""

	# if error is generate then handle
	# by the except block
	except:

		equation.set(" error ")
		expression = ""


# Function to clear the contents
# of text entry box
def clear():
	global expression
	expression = ""
	equation.set("")


# Driver code
if __name__ == "__main__":
	# create a GUI window
	gui = Tk()

	# set the background colour of GUI window
	gui.configure(background="light green")

	# set the title of GUI window
	gui.title("Simple Calculator")

	# set the configuration of GUI window
	gui.geometry("270x150")

	# StringVar() is the variable class
	# we create an instance of this class
	equation = StringVar()

	# create the text entry box for
	# showing the expression .
	expression_field = Entry(gui, textvariable=equation)

	# grid method is used for placing
	# the widgets at respective positions
	# in table like structure .
	expression_field.grid(columnspan=4, ipadx=70)

	# create a Buttons and place at a particular
	# location inside the root window .
	# when user press the button, the command or
	# function affiliated to that button is executed .
	button1 = Button(gui, text=' 1 ', fg='black', bg='red',
					command=lambda: press(1), height=1, width=7)
	button1.grid(row=2, column=0)

	button2 = Button(gui, text=' 2 ', fg='black', bg='red',
					command=lambda: press(2), height=1, width=7)
	button2.grid(row=2, column=1)

	button3 = Button(gui, text=' 3 ', fg='black', bg='red',
					command=lambda: press(3), height=1, width=7)
	button3.grid(row=2, column=2)

	button4 = Button(gui, text=' 4 ', fg='black', bg='red',
					command=lambda: press(4), height=1, width=7)
	button4.grid(row=3, column=0)

	button5 = Button(gui, text=' 5 ', fg='black', bg='red',
					command=lambda: press(5), height=1, width=7)
	button5.grid(row=3, column=1)

	button6 = Button(gui, text=' 6 ', fg='black', bg='red',
					command=lambda: press(6), height=1, width=7)
	button6.grid(row=3, column=2)

	button7 = Button(gui, text=' 7 ', fg='black', bg='red',
					command=lambda: press(7), height=1, width=7)
	button7.grid(row=4, column=0)

	button8 = Button(gui, text=' 8 ', fg='black', bg='red',
					command=lambda: press(8), height=1, width=7)
	button8.grid(row=4, column=1)

	button9 = Button(gui, text=' 9 ', fg='black', bg='red',
					command=lambda: press(9), height=1, width=7)
	button9.grid(row=4, column=2)

	button0 = Button(gui, text=' 0 ', fg='black', bg='red',
					command=lambda: press(0), height=1, width=7)
	button0.grid(row=5, column=0)

	plus = Button(gui, text=' + ', fg='black', bg='red',
				command=lambda: press("+"), height=1, width=7)
	plus.grid(row=2, column=3)

	minus = Button(gui, text=' - ', fg='black', bg='red',
				command=lambda: press("-"), height=1, width=7)
	minus.grid(row=3, column=3)

	multiply = Button(gui, text=' * ', fg='black', bg='red',
					command=lambda: press("*"), height=1, width=7)
	multiply.grid(row=4, column=3)

	divide = Button(gui, text=' / ', fg='black', bg='red',
					command=lambda: press("/"), height=1, width=7)
	divide.grid(row=5, column=3)

	equal = Button(gui, text=' = ', fg='black', bg='red',
				command=equalpress, height=1, width=7)
	equal.grid(row=5, column=2)

	clear = Button(gui, text='Clear', fg='black', bg='red',
				command=clear, height=1, width=7)
	clear.grid(row=5, column='1')

	Decimal= Button(gui, text='.', fg='black', bg='red',
					command=lambda: press('.'), height=1, width=7)
	Decimal.grid(row=6, column=0)
	# start the GUI
	gui.mainloop()
