# %%
from tkinter import*
root=Tk()
root.geometry('500x500')
root.minsize(500,500)
root.maxsize(500,500)
root.iconbitmap('images.ico')
root.title('By Vipul')
root.config(background="grey")


Button(root,text="close",command=root.destroy).pack()
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk
import mysql.connector as mysql
import tkinter.messagebox as tmsg

def insert():
    fname=A1.get()
    lname=B1.get()
    email=C1.get()
    contact=D1.get()

    if(fname==" " or lname==" " or email==" " or contact==" "):
        tmsg.showinfo("Insert Status","Please Enter All Details")
    else:
        con=mysql.connect(host="localhost",user="root",password="",database="python-tkinter")
        custor=con.cursor()
        custor.execute("insert into student values('"+fname+"','"+lname+"','"+email+"','"+contact+"')")
        custor.execute("commit")

        tmsg.showinfo("Insert Status","Inserted Successfully")

        con.close()


window = Tk()
window.title("By Vipul")
window.iconbitmap("images.ico")
window.geometry('400x400')
# window.configure(background = "grey");

A1=StringVar()
B1=StringVar()
C1=StringVar()
D1=StringVar()

a = Label(window ,text = "First Name").grid(row = 0,column = 0)
b = Label(window ,text = "Last Name").grid(row = 1,column = 0)
c = Label(window ,text = "Email Id").grid(row = 2,column = 0)
d = Label(window ,text = "Contact Number").grid(row = 3,column = 0)
a1 = Entry(window,textvariable=A1).grid(row = 0,column = 1)
b1 = Entry(window,textvariable=B1).grid(row = 1,column = 1)
c1 = Entry(window,textvariable=C1).grid(row = 2,column = 1)
d1 = Entry(window,textvariable=D1).grid(row = 3,column = 1)


btn = ttk.Button(window ,text="Submit",command=insert).grid(row=4,column=0)



window.mainloop()

# %%
from tkinter import*
import tkinter.messagebox as tmsg
root=Tk()
root.geometry('500x500')
root.title("By Vipul")
root.iconbitmap("images.ico")
# root.configure(background = "grey")


def classA():
    
    var1 = StringVar()
    var2 = StringVar()
    var3 = StringVar()
    var4 = StringVar()
    var5 = StringVar()
    Label(root,text="Click To Present Student",justify=CENTER,padx=14,font="verdana  10").pack()

    
    Checkbutton(root, text="Jadav Vipul", variable=var1).pack()
    Checkbutton(root, text="Dabhi harpal", variable=var2).pack()
    Checkbutton(root, text="Jakasaniya Yash", variable=var3).pack()
    Checkbutton(root, text="Gor Jeel", variable=var4).pack()
    Checkbutton(root, text="Gundigara Aditya", variable=var5).pack()

    Button(root,text="Save",command=order).pack()
    Button(root,text="Close",command=root.destroy).pack()


def classB():
    
    var1 = StringVar()
    var2 = StringVar()
    var3 = StringVar()
    var4 = StringVar()
    var5 = StringVar()
    Label(root,text="Click To Present Student",justify=CENTER,padx=14,font="verdana  10").pack()

    
    Checkbutton(root, text="Sojitra Aashish", variable=var1).pack()
    Checkbutton(root, text="Sojitra Abhay", variable=var2).pack()
    Checkbutton(root, text="Herma Bhargau", variable=var3).pack()
    Checkbutton(root, text="Sakriya Darshan", variable=var4).pack()
    Checkbutton(root, text="Rajodiya Krutik", variable=var5).pack()

    Button(root,text="Save",command=order).pack()
    Button(root,text="Close",command=root.destroy).pack()

def classC():
    
    var1 = StringVar()
    var2 = StringVar()
    var3 = StringVar()
    var4 = StringVar()
    var5 = StringVar()
    Label(root,text="Click To Present Student",justify=CENTER,padx=14,font="verdana  10").pack()

    
    Checkbutton(root, text="Markana Dip", variable=var1).pack()
    Checkbutton(root, text="Markana Divyesh", variable=var2).pack()
    Checkbutton(root, text="Gupta Krishna", variable=var3).pack()
    Checkbutton(root, text="Nanda Amit", variable=var4).pack()
    Checkbutton(root, text="Smit Suhagiya", variable=var5).pack()

    Button(root,text="Save",command=order).pack()
    Button(root,text="Close",command=root.destroy).pack()

def classD():
    
    var1 = StringVar()
    var2 = StringVar()
    var3 = StringVar()
    var4 = StringVar()
    var5 = StringVar()
    Label(root,text="Click To Present Student",justify=CENTER,padx=14,font="verdana  10").pack()

    
    Checkbutton(root, text="Jethva Darshan", variable=var1).pack()
    Checkbutton(root, text="Baraiya Kishor", variable=var2).pack()
    Checkbutton(root, text="Naliyadhara Jenish", variable=var3).pack()
    Checkbutton(root, text="Japdiya Tushar", variable=var4).pack()
    Checkbutton(root, text="Nakum Chintan", variable=var5).pack()

    def order():
        # tmsg.showinfo(f"Attandance",f"var1.get()")
        print(var1.get())
    # Button(root,text="Save",command=order).pack()
    Button(root,text="Save",command=order).pack()
    Button(root,text="Close",command=root.destroy).pack()





Label(root,text="COMPUTER ENGINEERING",justify=CENTER,font="lucida 19 bold").pack()

mainmenu=Menu(root)

m1=Menu(mainmenu,tearoff=0)
m1.add_command(label="Class-A",command=classA)
m1.add_command(label="Class-B",command=classB)
m1.add_command(label="Class-C",command=classC)
m1.add_command(label="Class-D",command=classD)
mainmenu.add_cascade(label="CLASS",menu=m1)
root.config(menu=mainmenu)
root.mainloop()
